# %%
#Recognition model conversion
ONNX_MODEL_PATH="./model-batch.onnx"
TRT_MODEL = "./model-batch.plan"
# !trtexec --onnx=$ONNX_MODEL_PATH  --explicitBatch --workspace=16382  --optShapes=input0:1x112x112x3 --maxShapes=input0:0:128x112x112x3 --minShapes=input0:1x112x112x3 --saveEngine=$TRT_MODEL
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8001] # trtexec --onnx=./retinaface-320-batch.onnx --explicitBatch --workspace=16382 --optShapes=input0:1x112x112x3 --maxShapes=input0:0:128x112x112x3 --minShapes=input0:1x112x112x3 --saveEngine=./retinaface.plan
# [11/24/2021-21:46:24] [I] === Model Options ===
# [11/24/2021-21:46:24] [I] Format: ONNX
# [11/24/2021-21:46:24] [I] Model: ./retinaface-320-batch.onnx
# [11/24/2021-21:46:24] [I] Output:
# [11/24/2021-21:46:24] [I] === Build Options ===
# [11/24/2021-21:46:24] [I] Max batch: explicit
# [11/24/2021-21:46:24] [I] Workspace: 16382 MiB
# [11/24/2021-21:46:24] [I] minTiming: 1
# [11/24/2021-21:46:24] [I] avgTiming: 8
# [11/24/2021-21:46:24] [I] Precision: FP32
# [11/24/2021-21:46:24] [I] Calibration:
# [11/24/2021-21:46:24] [I] Refit: Disabled
# [11/24/2021-21:46:24] [I] Sparsity: Disabled
# [11/24/2021-21:46:24] [I] Safe mode: Disabled
# [11/24/2021-21:46:24] [I] Restricted mode: Disabled
# ...

# %%
#Detection model conversion
ONNX_MODEL_PATH="./retinaface-320-batch.onnx"
TRT_MODEL = "./retinaface.plan"
# !trtexec --onnx=$ONNX_MODEL_PATH  --explicitBatch --workspace=16382  --optShapes=input0:1x3x320x320 --maxShapes=input0:128x3x320x320 --minShapes=input0:1x3x320x320 --saveEngine=$TRT_MODEL
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8001] # trtexec --onnx=./retinaface-320-batch.onnx --explicitBatch --workspace=16382 --optShapes=input0:1x3x320x320 --maxShapes=input0:128x3x320x320 --minShapes=input0:1x3x320x320 --saveEngine=./retinaface.plan
# [11/24/2021-21:51:06] [I] === Model Options ===
# [11/24/2021-21:51:06] [I] Format: ONNX
# [11/24/2021-21:51:06] [I] Model: ./retinaface-320-batch.onnx
# [11/24/2021-21:51:06] [I] Output:
# [11/24/2021-21:51:06] [I] === Build Options ===
# [11/24/2021-21:51:06] [I] Max batch: explicit
# [11/24/2021-21:51:06] [I] Workspace: 16382 MiB
# [11/24/2021-21:51:06] [I] minTiming: 1
# [11/24/2021-21:51:06] [I] avgTiming: 8
# [11/24/2021-21:51:06] [I] Precision: FP32
# [11/24/2021-21:51:06] [I] Calibration:
# [11/24/2021-21:51:06] [I] Refit: Disabled
# [11/24/2021-21:51:06] [I] Sparsity: Disabled
# [11/24/2021-21:51:06] [I] Safe mode: Disabled
# [11/24/2021-21:51:06] [I] Restricted mode: Disabled
# ...
